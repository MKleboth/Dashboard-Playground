# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import panel as pn
pn.extension("tabulator")

import hvplot.pandas
from datetime import datetime as dt
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
data_covid = pd.read_csv("data/covid.csv")

# %%
data_covid.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
data_covid["date"] = data_covid.date.apply(lambda x: dt.strptime(x,"%Y-%m-%d"))
idf = data_covid.interactive()

# %%
if 'data' not in pn.state.cache.keys():
    df = pd.read_csv("data/covid.csv")
    pn.state.cache['data'] = df.copy()
else :
    df = pn.state.cache['data']

# %%
multi_select = pn.widgets.MultiSelect(name='MultiSelect', value=["OWID_WRL"],
    options=df.iso_code.unique().tolist(), size=8)

# %%
max_date = max(data_covid.date)
min_date = min(data_covid.date)
date_slider = pn.widgets.DateRangeSlider(name='Date Slider', start=min_date,
                                    end=max_date, value=(min_date,max_date))

date_slider
# Out:
# DateRangeSlider(end=Timestamp('2022-05-11 0..., name='Date Slider', start=Timestamp('2020-01-01 0..., value=(Timestamp('2020-01-01 00:..., value_end=Timestamp('2022-05-11 0..., value_start=Timestamp('2020-01-01 0...)

# %%
case_number_pipe = (
    idf[
        (idf.year >= date_slider[1]) &
        (idf.year <= date_slider[0]) &
        (idf.iso_code.isin(multi_select.value))
    ]
    .groupby(['country', 'year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
data_covid.groupby(["continent","date"])["total_cases"].mean().to_frame()
# Out:
#                            total_cases
# continent     date
# Africa        2020-02-07           NaN
#               2020-02-08           NaN
#               2020-02-09           NaN
#               2020-02-10           NaN
#               2020-02-11           NaN
# ...                                ...
# South America 2022-05-07  4.374826e+06
#               2022-05-08  4.376689e+06
#               2022-05-09  4.377878e+06
#               2022-05-10  4.379884e+06
#               2022-05-11  4.381974e+06
#
# [5086 rows x 1 columns]
